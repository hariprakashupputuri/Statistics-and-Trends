# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
furniture_data = pd.read_csv('Furniture.csv')

# %%
furniture_data
# Out:
#            price        cost  sales  profit_margin  inventory  \
# 0     218.543053  181.610932     40      16.899243        105
# 1     477.821438  385.033827      7      19.418888        192
# 2     379.397274  276.736765     32      27.058842         59
# 3     319.396318  281.841334     48      11.758114         45
# 4     120.208388   69.743681     19      41.981019         35
# ...          ...         ...    ...            ...        ...
# 2495  271.546466  233.247261      8      14.104107        102
# 2496  309.775563  169.680310     24      45.224760          9
# 2497  439.509716  277.390903     48      36.886286        127
# 2498  491.332705  405.987306     38      17.370185          6
# 2499  233.412894  172.474611      6      26.107505         55
#
#       discount_percentage  delivery_days category material  color  location  \
# 0               27.796433              9      Bed  Plastic    Red     Rural
# ...

# %%
# Generate descriptive statistics
furniture_describe = furniture_data.describe()
furniture_describe
# Out:
#              price         cost        sales  profit_margin    inventory  \
# count  2500.000000  2500.000000  2500.000000    2500.000000  2500.000000
# mean    274.495219   191.930107    24.924000      30.208571    97.715600
# std     130.898452    98.590751    14.050067      11.536804    57.616228
# min      50.704297    26.505895     1.000000      10.017692     0.000000
# 25%     159.104890   106.399135    13.000000      20.230697    50.000000
# 50%     277.641809   189.336329    25.000000      30.297911    94.000000
# 75%     387.378046   263.188280    37.000000      40.134205   147.000000
# max     499.872953   447.022911    49.000000      49.999535   199.000000
#
#        discount_percentage  delivery_days       revenue
# count          2500.000000     2500.00000   2500.000000
# mean             14.947616        4.89400   5926.853657
# std               8.621547        2.55902   6902.737604
# min               0.005556        1.00000 -14214.565505
# ...

# %%
# Calculate Mean
mean_values = furniture_data.mean(numeric_only=True)
print("Mean:\n", mean_values)

# Calculate Median
median_values = furniture_data.median(numeric_only=True)
print("\nMedian:\n", median_values)

# Calculate Standard Deviation
std_dev_values = furniture_data.std(numeric_only=True)
print("\nStandard Deviation:\n", std_dev_values)

# Calculate Skewness
skewness_values = furniture_data.skew(numeric_only=True)
print("\nSkewness:\n", skewness_values)

# Calculate Kurtosis
kurtosis_values = furniture_data.kurtosis(numeric_only=True)
print("\nKurtosis:\n", kurtosis_values)
# Out:
# Mean:
#  price                   274.495219
# cost                    191.930107
# sales                    24.924000
# profit_margin            30.208571
# inventory                97.715600
# discount_percentage      14.947616
# delivery_days             4.894000
# revenue                5926.853657
# dtype: float64
#
# Median:
#  price                   277.641809
# cost                    189.336329
# sales                    25.000000
# profit_margin            30.297911
# inventory                94.000000
# discount_percentage      14.915143
# delivery_days             5.000000
# revenue                5523.232714
# dtype: float64
#
# Standard Deviation:
#  price                   130.898452
# cost                     98.590751
# sales                    14.050067
# profit_margin            11.536804
# inventory                57.616228
# discount_percentage       8.621547
# delivery_days             2.559020
# revenue                6902.737604
# dtype: float64
#
# Skewness:
# ...

# %%
# correlation matrix
furniture_corr = furniture_data.select_dtypes(include=['float64', 'int64']).corr()
print(furniture_corr)
# Out:
#                         price      cost     sales  profit_margin  inventory  \
# price                1.000000  0.932787 -0.006363      -0.023581   0.029306
# cost                 0.932787  1.000000  0.001666      -0.346914   0.018150
# sales               -0.006363  0.001666  1.000000      -0.022618  -0.028932
# profit_margin       -0.023581 -0.346914 -0.022618       1.000000   0.025438
# inventory            0.029306  0.018150 -0.028932       0.025438   1.000000
# discount_percentage -0.025858 -0.026598 -0.008092      -0.000530   0.006816
# delivery_days        0.016220  0.024013  0.018719      -0.016404  -0.003220
# revenue              0.383215  0.360730  0.496033      -0.018424  -0.013378
#
#                      discount_percentage  delivery_days   revenue
# price                          -0.025858       0.016220  0.383215
# cost                           -0.026598       0.024013  0.360730
# sales                          -0.008092       0.018719  0.496033
# ...

# %%
# Function to plot a histogram of a specified column
def plot_histogram(column_name):
    plt.figure(figsize=(8, 6))
    plt.hist(furniture_data[column_name], bins=20, edgecolor='black')
    plt.title(f"Distribution of {column_name.capitalize()}")
    plt.xlabel(column_name.capitalize())
    plt.ylabel("Frequency")
    plt.show()

# Plotting the histogram for the 'price' column
plot_histogram("price")

# %%
# Function to plot scatter plot showing the relationship between price and revenue
def plot_scatter_price_vs_revenue():
    """
    Plots a scatter plot showing the relationship between price and revenue.
    Each point represents a furniture item, illustrating how price affects revenue.
    """
    plt.figure(figsize=(10, 6))
    plt.scatter(furniture_data['price'], furniture_data['revenue'], alpha=0.5, edgecolor='k')
    plt.title("Relationship between Price and Revenue")
    plt.xlabel("Price")
    plt.ylabel("Revenue")
    plt.grid(True)
    plt.show()

# Plotting the scatter plot for price vs revenue
plot_scatter_price_vs_revenue()

# %%
 # Function to plot heatmap of the correlation matrix for numerical features
def plot_heatmap_correlation():
    """
    Plots a heatmap of the correlation matrix for numerical features in the furniture dataset.
    This visual representation helps identify strong positive or negative relationships.
    """
    # Calculate correlation matrix within the function
    furniture_corr = furniture_data.corr(numeric_only=True)
    
    plt.figure(figsize=(8,6))
    sns.heatmap(furniture_corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
    plt.title("Correlation Matrix Heatmap")
    plt.show()

# Plotting the heatmap for the correlation matrix
plot_heatmap_correlation()
